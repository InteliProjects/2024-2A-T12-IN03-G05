# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.statespace.sarimax import SARIMAX
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import optuna

# %%
df = pd.read_csv('../../df_analise_origem_VT.csv')

# %%
df.set_index('AnoMes', inplace=True)    

if isinstance(df.index, pd.PeriodIndex):
        df.index = df.index.to_timestamp() 
else:
        df.index = pd.to_datetime(df.index)

# %%
# Verifique se há valores ausentes e preencha ou remova-os
df = df.dropna()

# Converta todas as colunas para tipos numéricos, se necessário
df = df.apply(pd.to_numeric, errors='coerce')

# Selecione as features (todas as colunas menos 'Vl Liquido Final', 'VL Tabela', 'Vl Bruto')
X = df.drop(columns=['Vl Liquido Final', 'Vl Bruto', 'VL Tabela', 'Origem'])
y = df['Vl Liquido Final']

# Divida os dados em treinamento e teste
train_size = int(len(y) * 0.8)
train_X, test_X = X[:train_size], X[train_size:]
train_y, test_y = y[:train_size], y[train_size:]

# %%
print(f"Realizando otimização de hiperparâmetros para Cachoeiro...")

# Definir a função objetivo para o Optuna
def objective(trial):
    # Definir o espaço de busca dos hiperparâmetros
    p = trial.suggest_int('p', 0, 3)
    d = trial.suggest_int('d', 0, 2)
    q = trial.suggest_int('q', 0, 3)
    P = trial.suggest_int('P', 0, 3)
    D = trial.suggest_int('D', 0, 2)
    Q = trial.suggest_int('Q', 0, 3)
    s = 12  # Período sazonal fixo em 12 (mensal)

    try:
        # Treinar o modelo SARIMAX com os hiperparâmetros sugeridos
        model = SARIMAX(train_y, exog=train_X, order=(p, d, q), seasonal_order=(P, D, Q, s))
        model_fit = model.fit(disp=False)
        
        # Fazer previsões no conjunto de teste
        forecast_test = model_fit.forecast(steps=len(test_y), exog=test_X)
        
        # Calcular o erro quadrático médio (RMSE)
        rmse = np.sqrt(mean_squared_error(test_y, forecast_test))
    except:
        # Em caso de erro na modelagem, retornar um valor grande
        rmse = np.inf

    return rmse

# Criar o estudo Optuna e executar a otimização
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)

# Obter os melhores hiperparâmetros
best_params = study.best_params
print("Melhores hiperparâmetros encontrados:")
print(best_params)
# Out:
# [I 2024-09-27 08:45:54,537] A new study created in memory with name: no-name-5a78659d-2e06-412a-a4f8-be475fd1f6c4
# Realizando otimização de hiperparâmetros para Cachoeiro...
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# [I 2024-09-27 08:45:57,029] Trial 0 finished with value: 3580186.988904146 and parameters: {'p': 3, 'd': 1, 'q': 2, 'P': 1, 'D': 2, 'Q': 0}. Best is trial 0 with value: 3580186.988904146.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# [I 2024-09-27 08:45:57,197] Trial 1 finished with value: 2653561.4603699995 and parameters: {'p': 1, 'd': 1, 'q': 0, 'P': 0, 'D': 1, 'Q': 1}. Best is trial 1 with value: 2653561.4603699995.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# [I 2024-09-27 08:46:13,810] Trial 2 finished with value: 4441337.7800105475 and parameters: {'p': 3, 'd': 2, 'q': 0, 'P': 2, 'D': 2, 'Q': 2}. Best is trial 1 with value: 2653561.4603699995.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# [I 2024-09-27 08:46:14,957] Trial 3 finished with value: 1189743.5890370205 and parameters: {'p': 0, 'd': 0, 'q': 1, 'P': 1, 'D': 1, 'Q': 1}. Best is trial 3 with value: 1189743.5890370205.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# [I 2024-09-27 08:46:18,019] Trial 4 finished with value: 3332098.863871261 and parameters: {'p': 0, 'd': 2, 'q': 1, 'P': 3, 'D': 2, 'Q': 0}. Best is trial 3 with value: 1189743.5890370205.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# [I 2024-09-27 08:46:19,680] Trial 5 finished with value: 2483373.8616903126 and parameters: {'p': 1, 'd': 2, 'q': 1, 'P': 2, 'D': 0, 'Q': 2}. Best is trial 3 with value: 1189743.5890370205.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# [I 2024-09-27 08:46:42,108] Trial 6 finished with value: 3382311.8435785673 and parameters: {'p': 1, 'd': 1, 'q': 3, 'P': 1, 'D': 2, 'Q': 3}. Best is trial 3 with value: 1189743.5890370205.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# [I 2024-09-27 08:46:43,372] Trial 7 finished with value: 1350547.1796200718 and parameters: {'p': 2, 'd': 2, 'q': 2, 'P': 1, 'D': 0, 'Q': 1}. Best is trial 3 with value: 1189743.5890370205.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# [I 2024-09-27 08:46:53,809] Trial 8 finished with value: 3366794.172790974 and parameters: {'p': 3, 'd': 2, 'q': 2, 'P': 2, 'D': 2, 'Q': 0}. Best is trial 3 with value: 1189743.5890370205.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:1009: UserWarning: Non-invertible starting seasonal moving average Using zeros as starting parameters.
#   warn('Non-invertible starting seasonal moving average'
# [I 2024-09-27 08:46:54,266] Trial 9 finished with value: 1381415.269858831 and parameters: {'p': 2, 'd': 2, 'q': 2, 'P': 0, 'D': 0, 'Q': 1}. Best is trial 3 with value: 1189743.5890370205.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# [I 2024-09-27 08:46:59,107] Trial 10 finished with value: 1183211.1414439215 and parameters: {'p': 0, 'd': 0, 'q': 3, 'P': 3, 'D': 1, 'Q': 3}. Best is trial 10 with value: 1183211.1414439215.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# [I 2024-09-27 08:47:04,186] Trial 11 finished with value: 1183211.1414439215 and parameters: {'p': 0, 'd': 0, 'q': 3, 'P': 3, 'D': 1, 'Q': 3}. Best is trial 10 with value: 1183211.1414439215.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# [I 2024-09-27 08:47:08,527] Trial 12 finished with value: 1183211.1414439215 and parameters: {'p': 0, 'd': 0, 'q': 3, 'P': 3, 'D': 1, 'Q': 3}. Best is trial 10 with value: 1183211.1414439215.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# [I 2024-09-27 08:47:12,089] Trial 13 finished with value: 1183211.1414439215 and parameters: {'p': 0, 'd': 0, 'q': 3, 'P': 3, 'D': 1, 'Q': 3}. Best is trial 10 with value: 1183211.1414439215.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# [I 2024-09-27 08:47:22,270] Trial 14 finished with value: 1175937.15196507 and parameters: {'p': 1, 'd': 0, 'q': 3, 'P': 3, 'D': 1, 'Q': 2}. Best is trial 14 with value: 1175937.15196507.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# [I 2024-09-27 08:47:32,186] Trial 15 finished with value: 1175937.15196507 and parameters: {'p': 1, 'd': 0, 'q': 3, 'P': 3, 'D': 1, 'Q': 2}. Best is trial 14 with value: 1175937.15196507.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# [I 2024-09-27 08:47:33,941] Trial 16 finished with value: 1583050.6633759423 and parameters: {'p': 2, 'd': 0, 'q': 3, 'P': 2, 'D': 0, 'Q': 2}. Best is trial 14 with value: 1175937.15196507.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# [I 2024-09-27 08:47:51,682] Trial 17 finished with value: 3416908.704929221 and parameters: {'p': 1, 'd': 1, 'q': 2, 'P': 3, 'D': 1, 'Q': 2}. Best is trial 14 with value: 1175937.15196507.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# [I 2024-09-27 08:47:54,147] Trial 18 finished with value: 1159237.3141230512 and parameters: {'p': 1, 'd': 1, 'q': 3, 'P': 2, 'D': 0, 'Q': 2}. Best is trial 18 with value: 1159237.3141230512.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# [I 2024-09-27 08:47:55,461] Trial 19 finished with value: 1170586.6200367357 and parameters: {'p': 2, 'd': 1, 'q': 2, 'P': 2, 'D': 0, 'Q': 2}. Best is trial 18 with value: 1159237.3141230512.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:47:56,257] Trial 20 finished with value: 1169029.902831927 and parameters: {'p': 2, 'd': 1, 'q': 2, 'P': 2, 'D': 0, 'Q': 1}. Best is trial 18 with value: 1159237.3141230512.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:47:57,005] Trial 21 finished with value: 1169029.902831927 and parameters: {'p': 2, 'd': 1, 'q': 2, 'P': 2, 'D': 0, 'Q': 1}. Best is trial 18 with value: 1159237.3141230512.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:47:57,636] Trial 22 finished with value: 1148300.7902752832 and parameters: {'p': 2, 'd': 1, 'q': 1, 'P': 2, 'D': 0, 'Q': 1}. Best is trial 22 with value: 1148300.7902752832.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:47:58,303] Trial 23 finished with value: 1148300.7902752832 and parameters: {'p': 2, 'd': 1, 'q': 1, 'P': 2, 'D': 0, 'Q': 1}. Best is trial 22 with value: 1148300.7902752832.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:47:59,084] Trial 24 finished with value: 1148300.7902752832 and parameters: {'p': 2, 'd': 1, 'q': 1, 'P': 2, 'D': 0, 'Q': 1}. Best is trial 22 with value: 1148300.7902752832.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:47:59,329] Trial 25 finished with value: 1120215.1128612324 and parameters: {'p': 3, 'd': 1, 'q': 1, 'P': 1, 'D': 0, 'Q': 0}. Best is trial 25 with value: 1120215.1128612324.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:47:59,490] Trial 26 finished with value: 1117998.4534903988 and parameters: {'p': 3, 'd': 1, 'q': 0, 'P': 1, 'D': 0, 'Q': 0}. Best is trial 26 with value: 1117998.4534903988.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:47:59,650] Trial 27 finished with value: 1117998.4534903988 and parameters: {'p': 3, 'd': 1, 'q': 0, 'P': 1, 'D': 0, 'Q': 0}. Best is trial 26 with value: 1117998.4534903988.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:47:59,770] Trial 28 finished with value: 1278244.3765121177 and parameters: {'p': 3, 'd': 1, 'q': 0, 'P': 0, 'D': 0, 'Q': 0}. Best is trial 26 with value: 1117998.4534903988.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:47:59,946] Trial 29 finished with value: 1117998.4534903988 and parameters: {'p': 3, 'd': 1, 'q': 0, 'P': 1, 'D': 0, 'Q': 0}. Best is trial 26 with value: 1117998.4534903988.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:48:00,124] Trial 30 finished with value: 1117998.4534903988 and parameters: {'p': 3, 'd': 1, 'q': 0, 'P': 1, 'D': 0, 'Q': 0}. Best is trial 26 with value: 1117998.4534903988.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:48:00,306] Trial 31 finished with value: 1117998.4534903988 and parameters: {'p': 3, 'd': 1, 'q': 0, 'P': 1, 'D': 0, 'Q': 0}. Best is trial 26 with value: 1117998.4534903988.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:48:00,397] Trial 32 finished with value: 1278244.3765121177 and parameters: {'p': 3, 'd': 1, 'q': 0, 'P': 0, 'D': 0, 'Q': 0}. Best is trial 26 with value: 1117998.4534903988.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:48:00,573] Trial 33 finished with value: 1117998.4534903988 and parameters: {'p': 3, 'd': 1, 'q': 0, 'P': 1, 'D': 0, 'Q': 0}. Best is trial 26 with value: 1117998.4534903988.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:48:00,764] Trial 34 finished with value: 1117998.4534903988 and parameters: {'p': 3, 'd': 1, 'q': 0, 'P': 1, 'D': 0, 'Q': 0}. Best is trial 26 with value: 1117998.4534903988.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:48:00,877] Trial 35 finished with value: 1278244.3765121177 and parameters: {'p': 3, 'd': 1, 'q': 0, 'P': 0, 'D': 0, 'Q': 0}. Best is trial 26 with value: 1117998.4534903988.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:48:01,043] Trial 36 finished with value: 2817744.4046414974 and parameters: {'p': 3, 'd': 2, 'q': 0, 'P': 1, 'D': 0, 'Q': 0}. Best is trial 26 with value: 1117998.4534903988.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:48:01,222] Trial 37 finished with value: 1117998.4534903988 and parameters: {'p': 3, 'd': 1, 'q': 0, 'P': 1, 'D': 0, 'Q': 0}. Best is trial 26 with value: 1117998.4534903988.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:48:01,645] Trial 38 finished with value: 4338202.838671484 and parameters: {'p': 3, 'd': 2, 'q': 0, 'P': 1, 'D': 1, 'Q': 0}. Best is trial 26 with value: 1117998.4534903988.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:48:01,754] Trial 39 finished with value: 1278244.3765121177 and parameters: {'p': 3, 'd': 1, 'q': 0, 'P': 0, 'D': 0, 'Q': 0}. Best is trial 26 with value: 1117998.4534903988.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:48:01,925] Trial 40 finished with value: 1117998.4534903988 and parameters: {'p': 3, 'd': 1, 'q': 0, 'P': 1, 'D': 0, 'Q': 0}. Best is trial 26 with value: 1117998.4534903988.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:48:02,106] Trial 41 finished with value: 1117998.4534903988 and parameters: {'p': 3, 'd': 1, 'q': 0, 'P': 1, 'D': 0, 'Q': 0}. Best is trial 26 with value: 1117998.4534903988.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:48:02,293] Trial 42 finished with value: 1117998.4534903988 and parameters: {'p': 3, 'd': 1, 'q': 0, 'P': 1, 'D': 0, 'Q': 0}. Best is trial 26 with value: 1117998.4534903988.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:48:02,533] Trial 43 finished with value: 1120215.1128612324 and parameters: {'p': 3, 'd': 1, 'q': 1, 'P': 1, 'D': 0, 'Q': 0}. Best is trial 26 with value: 1117998.4534903988.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:48:02,698] Trial 44 finished with value: 1117998.4534903988 and parameters: {'p': 3, 'd': 1, 'q': 0, 'P': 1, 'D': 0, 'Q': 0}. Best is trial 26 with value: 1117998.4534903988.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# [I 2024-09-27 08:48:04,531] Trial 45 finished with value: 3473779.2143709282 and parameters: {'p': 3, 'd': 1, 'q': 0, 'P': 1, 'D': 2, 'Q': 1}. Best is trial 26 with value: 1117998.4534903988.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:48:04,674] Trial 46 finished with value: 1295198.9495596783 and parameters: {'p': 3, 'd': 1, 'q': 1, 'P': 0, 'D': 0, 'Q': 0}. Best is trial 26 with value: 1117998.4534903988.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:48:05,127] Trial 47 finished with value: 4338202.838671484 and parameters: {'p': 3, 'd': 2, 'q': 0, 'P': 1, 'D': 1, 'Q': 0}. Best is trial 26 with value: 1117998.4534903988.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# [I 2024-09-27 08:48:05,346] Trial 48 finished with value: 1117998.4534903988 and parameters: {'p': 3, 'd': 1, 'q': 0, 'P': 1, 'D': 0, 'Q': 0}. Best is trial 26 with value: 1117998.4534903988.
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:866: UserWarning: Too few observations to estimate starting parameters for seasonal ARMA. All parameters except for variances will be set to zeros.
#   warn('Too few observations to estimate starting parameters%s.'
# [I 2024-09-27 08:48:05,873] Trial 49 finished with value: 2578140.6308044083 and parameters: {'p': 2, 'd': 1, 'q': 0, 'P': 1, 'D': 1, 'Q': 1}. Best is trial 26 with value: 1117998.4534903988.
# Melhores hiperparâmetros encontrados:
# {'p': 3, 'd': 1, 'q': 0, 'P': 1, 'D': 0, 'Q': 0}

# %%
model_best = SARIMAX(train_y, exog=train_X, order=(best_params['p'], best_params['d'], best_params['q']), 
                     seasonal_order=(best_params['P'], best_params['D'], best_params['Q'], 12))
model_best_fit = model_best.fit(disp=False)

# Previsão no conjunto de teste com o melhor modelo
forecast_test_best = model_best_fit.forecast(steps=len(test_y), exog=test_X)

# Previsão futura de 12 meses
future_steps = 12
future_dates = pd.date_range(start=test_y.index[-1] + pd.DateOffset(months=1), periods=future_steps, freq='M')
future_X = X.iloc[-future_steps:]  # Assumindo que você tenha dados futuros para as features

forecast_future_best = model_best_fit.forecast(steps=future_steps, exog=future_X)

# Combine previsões de teste e futuras
all_forecast_best = np.concatenate([forecast_test_best, forecast_future_best])
all_dates_best = test_y.index.append(future_dates)

# Calcule as métricas de avaliação
mae = mean_absolute_error(test_y, forecast_test_best)
rmse = np.sqrt(mean_squared_error(test_y, forecast_test_best))
mape = np.mean(np.abs((test_y - forecast_test_best) / test_y)) * 100
r2 = r2_score(test_y, forecast_test_best)

# Exiba as métricas
print(f"Mean Absolute Error (MAE): {mae:.2f}")
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
print(f"Mean Absolute Percentage Error (MAPE): {mape:.2f}%")
print(f"R-squared (R²): {r2:.2f}")

# Plotando os valores reais, as previsões e a previsão futura
plt.figure(figsize=(12, 6))
plt.plot(test_y.index, test_y, label='Valores Reais')
plt.plot(all_dates_best, all_forecast_best, label='Previsões', linestyle='--', color='orange')
plt.axvline(x=test_y.index[-1], color='red', linestyle='--', label='Início da Previsão Futura')
plt.xlabel('Data')
plt.ylabel('Vl Liquido Final')
plt.title(f'Valores Reais vs Previsões com Previsão Futura de 12 Meses - Cachoeiro')
plt.legend()
plt.show()
# Out:
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# c:\Users\dudur\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\dudur\AppData\Local\Temp\ipykernel_21572\1591943361.py:10: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   future_dates = pd.date_range(start=test_y.index[-1] + pd.DateOffset(months=1), periods=future_steps, freq='M')
# Mean Absolute Error (MAE): 949768.43
# Root Mean Squared Error (RMSE): 1117998.45
# Mean Absolute Percentage Error (MAPE): 15.25%
# R-squared (R²): 0.46
